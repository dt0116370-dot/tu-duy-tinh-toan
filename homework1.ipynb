# %%
n=int(input())
print(n*2)
# Out:
# 10

# %%
a,b=map(int,input().split())
pi=3.14
t=a*b-((a/2)**2)*pi
print(f"{t:.2f}")
# Out:
# 30.38

# %%
a,b,c=map(int,input().split())
if a+b-c>0 :
   t=(a+b+c)/2
   s=(t*(t-a)*(t-b)*(t-c))**0.5
   print (s)
else :
   print ("khong phai 3 canh cua tam giac")
# Out:
# 6.0

# %% [markdown]
# ##Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này

# %%
a=list[av,x,ct,d,g,r,se,r,et,de,sf,e,we,re,fe,sf,ae,er,ht,se,sf]
