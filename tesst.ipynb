# %%
number = [3,4,5,2,5,6,4,7,8,6]
for k in number:
        if k % 2 == 0:
            print("yes")
        else :
            print("No")
# Out:
# No
# yes
# No
# yes
# No
# yes
# yes
# No
# yes
# yes
